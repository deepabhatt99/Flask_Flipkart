# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df =pd.read_csv("data.csv")
df.head()
# Out:
#      Reviewer_Name  Reviewer_Rating           Review_Title  \
# 0     Sumit  Kumar              5.0              Wonderful
# 1  BHARAT GALAGALI              5.0  Mind-blowing purchase
# 2  Paramjeet Singh              5.0                Awesome
# 3  Virendra  Kumar              5.0          Great product
# 4    jyoti solanki              5.0    Best in the market!
#
#                                          Review_Text  \
# 0  I think In this price category it's best dosa ...
# 1                   perfect tawa for Dosa..READ MORE
# 2  Excellent tawa. Made Paneer Tikka on first day...
# 3                            Nice 🙂 productREAD MORE
# 4             Delivery man is also good....READ MORE
#
#                           Place_of_Review   Date_of_Review  Up_Votes  \
# 0             Certified Buyer, Lakhisarai     Sumit  Kumar       211
# 1                 Certified Buyer, Hunsur  BHARAT GALAGALI       107
# 2           Certified Buyer, Rampura Phul  Paramjeet Singh        59
# 3  Certified Buyer, Chengalpattu District  Virendra  Kumar        77
# 4                 Certified Buyer, Mumbai    jyoti solanki        53
#
#    Down_Votes
# 0          39
# 1          17
# 2           8
# 3          12
# 4           7

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\pc\appdata\roaming\python\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\pc\appdata\roaming\python\python311\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\pc\appdata\roaming\python\python311\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\pc\appdata\roaming\python\python311\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from pandas>=1.2->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\pc\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\pc\appdata\roaming\python\python311\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in c:\users\pc\appdata\roaming\python\python311\site-packages (from wordcloud) (9.3.0)
# Requirement already satisfied: matplotlib in c:\users\pc\appdata\roaming\python\python311\site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\pc\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df["Reviewer_Rating"].value_counts()
# Out:
# 5.0    1408
# 4.0     589
# 3.0     288
# Name: Reviewer_Rating, dtype: int64

# %%
pd.unique(df["Reviewer_Rating"])
# Out:
# array([ 5.,  3.,  4., nan])

# %%
df.dropna(subset=['Reviewer_Rating'], inplace=True)

# %%
pd.unique(df["Reviewer_Rating"])
# Out:
# array([5., 3., 4.])

# %%
sns.countplot(data=df,
              x='Reviewer_Rating',
              order=df.Reviewer_Rating.value_counts().index)
# Out:
# <AxesSubplot: xlabel='Reviewer_Rating', ylabel='count'>

# %%
# Initialize an empty list to store the labels
pos_neg = []

# Loop through each rating and label them accordingly
for rating in df["Reviewer_Rating"]:
    if rating >= 5:
        pos_neg.append(1)
    else:
        pos_neg.append(0)

# Assign the labels to the 'label' column in the DataFrame
df['label'] = pos_neg

# %%
df.head()
# Out:
#      Reviewer_Name  Reviewer_Rating           Review_Title  \
# 0     Sumit  Kumar              5.0              Wonderful
# 1  BHARAT GALAGALI              5.0  Mind-blowing purchase
# 2  Paramjeet Singh              5.0                Awesome
# 3  Virendra  Kumar              5.0          Great product
# 4    jyoti solanki              5.0    Best in the market!
#
#                                          Review_Text  \
# 0  I think In this price category it's best dosa ...
# 1                   perfect tawa for Dosa..READ MORE
# 2  Excellent tawa. Made Paneer Tikka on first day...
# 3                            Nice 🙂 productREAD MORE
# 4             Delivery man is also good....READ MORE
#
#                           Place_of_Review   Date_of_Review  Up_Votes  \
# 0             Certified Buyer, Lakhisarai     Sumit  Kumar       211
# 1                 Certified Buyer, Hunsur  BHARAT GALAGALI       107
# 2           Certified Buyer, Rampura Phul  Paramjeet Singh        59
# 3  Certified Buyer, Chengalpattu District  Virendra  Kumar        77
# 4                 Certified Buyer, Mumbai    jyoti solanki        53
#
#    Down_Votes  label
# 0          39      1
# 1          17      1
# 2           8      1
# 3          12      1
# 4           7      1

# %%
df["label"].value_counts()
# Out:
# 1    1408
# 0     877
# Name: label, dtype: int64

# %%
## Spliting data

# %%
from sklearn.model_selection import train_test_split

# Assuming you have loaded your dataset into a DataFrame called 'data'

# Split the data into features (reviews) and labels (labels)
X = df['Review_Text']
y = df['label']  # Assuming your target variable is named 'label'

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# Print the number of training and testing examples
print('Loaded %d training examples and %d validation examples.\n' %(X_train.shape[0], X_test.shape[0]))
print('Example review in the training set:\n', X_train.iloc[10])

# Optionally, you can print the labels as well
print('Corresponding label in the training set:', y_train.iloc[10])
# Out:
# Loaded 2056 training examples and 229 validation examples.
#
# Example review in the training set:
#  Good and excellentREAD MORE
# Corresponding label in the training set: 1

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\pc\appdata\roaming\python\python311\site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\pc\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from scikit-learn) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from bs4 import BeautifulSoup

def cleanText(raw_text, remove_stopwords=False, stemming=False, split_text=False, remove_read_more=False):
    '''
    Convert a raw review to a cleaned review
    '''
    text = BeautifulSoup(raw_text, 'html.parser').get_text()
    
    # Remove "read more" if specified
    if remove_read_more:
        text = re.sub(r'read more', '', text, flags=re.IGNORECASE)
    
    letters_only = re.sub("[^a-zA-Z]", " ", text)
    words = letters_only.lower().split() 
    
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
        
    if stemming:
        stemmer = SnowballStemmer('english') 
        words = [stemmer.stem(w) for w in words]
        
    if split_text:
        return words
    
    return " ".join(words)

# Assuming you have a DataFrame called 'df' with a column named 'Review_Text'

# Clean the Review_Text column in the DataFrame
X_train = X_train.apply(cleanText, remove_read_more=True)

# Display a cleaned review from the DataFrame
print('Show a cleaned review in the DataFrame:\n', X_train.iloc[10])
# Out:
# Show a cleaned review in the DataFrame:
#  good and excellent

# %%
pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\users\pc\appdata\roaming\python\python311\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\pc\appdata\roaming\python\python311\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\pc\appdata\roaming\python\python311\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pc\appdata\roaming\python\python311\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\pc\appdata\roaming\python\python311\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: colorama in c:\program files\python311\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
## CountVectorizer with Mulinomial Naive Bayes (Benchmark Model)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# Initialize CountVectorizer
countVect = CountVectorizer()

# Transform the cleaned text data into a document-term matrix
X_train_countVect = countVect.fit_transform(X_train)

# Get the feature names from the vocabulary
feature_names = countVect.get_feature_names_out()

# Print the number of features
print("Number of features: %d\n" % len(feature_names))

# Print some feature names
print("Show some feature names:\n", feature_names[::1000])

# Train Multinomial Naive Bayes classifier
mnb = MultinomialNB()
mnb.fit(X_train_countVect, y_train)
# Out:
# Number of features: 944
#
# Show some feature names:
#  ['able']
# MultinomialNB()

# %%
X_train
# Out:
# 2231                                                   ok
# 1906    it is very useful product quality design non s...
# 1108                                perfect tawa for dosa
# 2036                                      awesome product
# 488        khub valo tawa ta light weight thanku flipkart
#                               ...
# 1141                                                 good
# 1917                     very good product i am satisfied
# 846                                             it s nice
# 922                                          best product
# 1827                         ok product bad paint quality
# Name: Review_Text, Length: 2056, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# Initialize CountVectorizer
countVect = CountVectorizer()

# Transform the cleaned text data into a document-term matrix
X_train_countVect = countVect.fit_transform(X_train)

# Get the feature names from the vocabulary
feature_names = countVect.get_feature_names_out()

# Print the number of features
print("Number of features: %d\n" % len(feature_names))

# Print some feature names
print("Show some feature names:\n", feature_names[:40])  # Print the first 40 feature names

# Train Multinomial Naive Bayes classifier
mnb = MultinomialNB()
mnb.fit(X_train_countVect, y_train)

# Print the trained Multinomial Naive Bayes classifier
print(mnb)
# Out:
# Number of features: 944
#
# Show some feature names:
#  ['able' 'about' 'above' 'according' 'acha' 'adirampattinam' 'adjust'
#  'affordable' 'after' 'again' 'al' 'alhamdulillah' 'aligent' 'all'
#  'allover' 'allthank' 'allways' 'almost' 'along' 'already' 'also'
#  'alsovalue' 'always' 'am' 'amazing' 'amount' 'an' 'and' 'another'
#  'anwsome' 'any' 'anyone' 'apart' 'app' 'appreciatable' 'approval' 'ar'
#  'are' 'area' 'around']
# MultinomialNB()

# %%
pip install --upgrade scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\pc\appdata\roaming\python\python311\site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\pc\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from scikit-learn) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pickle

# Serialize the CountVectorizer object
with open('countVect_imdb.pkl', 'wb') as file:
    pickle.dump(countVect, file)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score,roc_auc_score
def modelEvaluation(predictions):
    '''
    Print model evaluation to predicted result 
    '''
    print ("\nAccuracy on validation set: {:.4f}".format(accuracy_score(y_test, predictions)))
    print("\nAUC score : {:.4f}".format(roc_auc_score(y_test, predictions)))
    print("\nClassification report : \n", metrics.classification_report(y_test, predictions))
    print("\nConfusion Matrix : \n", metrics.confusion_matrix(y_test, predictions))

# %%
predictions = mnb.predict(countVect.transform(X_test))
modelEvaluation(predictions)
# Out:
# Accuracy on validation set: 0.6376
#
# AUC score : 0.6544
#
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.53      0.74      0.62        91
#            1       0.77      0.57      0.66       138
#
#     accuracy                           0.64       229
#    macro avg       0.65      0.65      0.64       229
# weighted avg       0.67      0.64      0.64       229
#
#
# Confusion Matrix :
#  [[67 24]
#  [59 79]]

# %%
import pickle
pickle.dump(mnb,open('Naive_Bayes_model.pkl','wb'))

# %%
## TfidfVectorizer with Logistic Regression

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# Initialize TfidfVectorizer
tfidf = TfidfVectorizer(min_df=5) # minimum document frequency of 5

# Transform the cleaned text data into a TF-IDF matrix
X_train_tfidf = tfidf.fit_transform(X_train)

# Print the number of features
print("Number of features : %d \n" %len(tfidf.get_feature_names_out())) 

# Print some feature names
print("Show some feature names : \n", tfidf.get_feature_names_out()[::1000])

# Logistic Regression
lr = LogisticRegression()
lr.fit(X_train_tfidf, y_train)
# Out:
# Number of features : 177
#
# Show some feature names :
#  ['affordable']
# LogisticRegression()

# %%
feature_names = np.array(tfidf.get_feature_names_out())
sorted_coef_index = lr.coef_[0].argsort()
print('\nTop 10 features with smallest coefficients :\n{}\n'.format(feature_names[sorted_coef_index[:10]]))
print('Top 10 features with largest coefficients : \n{}'.format(feature_names[sorted_coef_index[:-11:-1]]))
# Out:
# Top 10 features with smallest coefficients :
# ['average' 'not' 'but' 'just' 'ok' 'okay' 'handle' 'small' 'loose'
#  'coating']
#
# Top 10 features with largest coefficients :
# ['excellent' 'superb' 'very' 'flipkart' 'super' 'happy' 'wow' 'perfect'
#  'buy' 'best']

# %%
predictions = lr.predict(tfidf.transform(X_test))
modelEvaluation(predictions)
# Out:
# Accuracy on validation set: 0.5764
#
# AUC score : 0.5082
#
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.42      0.18      0.25        91
#            1       0.61      0.84      0.71       138
#
#     accuracy                           0.58       229
#    macro avg       0.51      0.51      0.48       229
# weighted avg       0.53      0.58      0.52       229
#
#
# Confusion Matrix :
#  [[ 16  75]
#  [ 22 116]]

# %%
from sklearn.model_selection import  GridSearchCV
from sklearn import metrics
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.pipeline import Pipeline
estimators = [("tfidf", TfidfVectorizer()), ("lr", LogisticRegression())]
model = Pipeline(estimators)


params = {"lr__C":[0.1, 1, 10], 
          "tfidf__min_df": [1, 3], 
          "tfidf__max_features": [1000, None], 
          "tfidf__ngram_range": [(1,1), (1,2)], 
          "tfidf__stop_words": [None, "english"]} 

grid = GridSearchCV(estimator=model, param_grid=params, scoring="accuracy", n_jobs=-1)
grid.fit(X_train, y_train)
print("The best paramenter set is : \n", grid.best_params_)


# Evaluate on the validaton set
predictions = grid.predict(X_test)
modelEvaluation(predictions)
# Out:
# The best paramenter set is :
#  {'lr__C': 1, 'tfidf__max_features': None, 'tfidf__min_df': 1, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': None}
#
# Accuracy on validation set: 0.6070
#
# AUC score : 0.5186
#
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.53      0.09      0.15        91
#            1       0.61      0.95      0.74       138
#
#     accuracy                           0.61       229
#    macro avg       0.57      0.52      0.45       229
# weighted avg       0.58      0.61      0.51       229
#
#
# Confusion Matrix :
#  [[  8  83]
#  [  7 131]]

# %%
## Word2Vec

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Pc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

def parseSent(review, tokenizer, remove_stopwords=False):

    raw_sentences = tokenizer.tokenize(review.strip())
    sentences = []
    for raw_sentence in raw_sentences:
        if len(raw_sentence) > 0:
            sentences.append(cleanText(raw_sentence, remove_stopwords, split_text=True))
    return sentences


# Parse each review in the training set into sentences
sentences = []
for review in X_train:
    sentences += parseSent(review, tokenizer,remove_stopwords=False)
    
print('%d parsed sentence in the training set\n'  %len(sentences))
print('Show a parsed sentence in the training set : \n',  sentences[10])
# Out:
# 2051 parsed sentence in the training set
#
# Show a parsed sentence in the training set :
#  ['good', 'and', 'excellent']

# %%
import nltk
nltk.download('punkt')

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

def parseSent(review, tokenizer, remove_stopwords=False):
    raw_sentences = tokenizer.tokenize(review.strip())
    sentences = []
    for raw_sentence in raw_sentences:
        if len(raw_sentence) > 0:
            sentences.append(cleanText(raw_sentence, remove_stopwords, split_text=True))
    return sentences

# Clean the text in X_train if it's not already cleaned
X_train_cleaned = X_train.apply(cleanText)

# Parse each review in the training set into sentences
sentences = []
for review in X_train_cleaned:
    sentences += parseSent(review, tokenizer, remove_stopwords=False)
    
print('%d parsed sentences in the training set\n' % len(sentences))
print('Show a parsed sentence in the training set:\n', sentences[10])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Pc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2051 parsed sentences in the training set
#
# Show a parsed sentence in the training set:
#  ['good', 'and', 'excellent']

# %%
sentences
# Out:
# [['ok'],
#  ['it',
#   'is',
#   'very',
#   'useful',
#   'product',
#   'quality',
#   'design',
#   'non',
#   'stick',
#   'coating',
#   'size',
#   'everything',
#   'is',
#   'nice',
#   'and',
#   'what',
#   'all',
#   'it',
#   'claims',
#   'meets',
#   'the',
#   'expectations',
#   'just',
#   'go',
#   'for',
#   'it'],
#  ['perfect', 'tawa', 'for', 'dosa'],
#  ['awesome', 'product'],
#  ['khub', 'valo', 'tawa', 'ta', 'light', 'weight', 'thanku', 'flipkart'],
#  ['helpful'],
#  ['good', 'quality'],
#  ['nice', 'product'],
#  ['nice'],
#  ['ok'],
#  ['good', 'and', 'excellent'],
#  ['awesome'],
#  ['good'],
#  ['good', 'thankyou'],
#  ['nice', 'products'],
#  ['it',
#   's',
#   'really',
#   'good',
#   'size',
#   'is',
#   'amazing',
#   'can',
#   'be',
#   'used',
#   'on',
#   'both',
#   'induction',
#   'as',
#   'well',
#   'as',
#   'on',
#   'gas',
#   'it',
#   's',
#   'non',
#   'sticky',
#   'but',
#   'the',
#   'colour',
#   'fades',
#   'away',
#   'quickly',
#   'otherwise',
#   'overall',
#   'product',
#   'is',
#   'good',
#   'u',
#   'can',
#   'go',
#   'for',
#   'it'],
#  ['useful'],
#  ['nice'],
#  ['it', 's', 'really', 'amazing', 'product'],
#  ['i',
#   'can',
#   't',
#   'use',
#   'this',
#   'product',
#   'and',
#   'i',
#   'am',
#   'giving',
#   'rating'],
#  ['product', 'ok'],
#  ['nice'],
#  ['excellent'],
#  ['it', 's', 'good', 'product'],
#  ['value', 'for', 'money'],
#  ['value', 'for', 'money', 'product'],
#  ['very', 'nice', 'product'],
#  ['good', 'product'],
#  ['nyc'],
#  ['wow', 'it', 'is', 'good', 'for', 'egg', 'fry', 'and', 'dosa'],
#  ['light', 'damage'],
#  ['nice', 'product'],
#  ['very', 'nice', 'product'],
#  ['ok'],
#  ['super', 'producht', 'must', 'buy', 'this'],
#  ['it', 's', 'good', 'and', 'awesome'],
#  ['good', 'product'],
#  ['very', 'good'],
#  ['beautiful', 'dal', 'ke', 'chille', 'bane', 'thank', 'u', 'flipcart'],
#  ['good', 'product'],
#  ['no', 'quality', 'products'],
#  ['very', 'nice'],
#  ['best'],
#  ['awesome', 'dosa', 'tawa', 'worth', 'to', 'buy'],
#  ['super'],
#  ['not', 'too', 'good'],
#  ['smarty', 'product'],
#  ['super',
#   'quality',
#   'good',
#   'coating',
#   'worthy',
#   'for',
#   'money',
#   'thank',
#   'you',
#   'flipkart'],
#  ['not', 'too', 'good', 'quality', 'just', 'ok'],
#  ['it', 's', 'it', 's', 'awesome', 'product', 'thanks', 'for', 'flipcard'],
#  ['pan',
#   'is',
#   'good',
#   'except',
#   'for',
#   'the',
#   'handle',
#   'which',
#   'does',
#   'not',
#   'fix',
#   'firmly'],
#  ['nice', 'masters'],
#  ['good', 'product'],
#  ['quality', 'is', 'not', 'bad'],
#  ['the', 'product', 'is', 'awesome', 'and', 'thanks', 'to', 'flipkart'],
#  ['good', 'product'],
#  ['best', 'value', 'for', 'money'],
#  ['very', 'nice', 'tawa', 'build', 'quality', 'good'],
#  ['awesome', 'product'],
#  ['recommend', 'it', 's', 'good'],
#  ['nice'],
#  ['good'],
#  ['awesome', 'product'],
#  ['smarty', 'product'],
#  ['very', 'good'],
#  ['ok'],
#  ['good'],
#  ['amazing'],
#  ['very', 'nice', 'pan', 'value', 'of', 'money'],
#  ['good'],
#  ['nice'],
#  ['it', 's', 'nice'],
#  ['look',
#   'wise',
#   'product',
#   'is',
#   'good',
#   'packaging',
#   'is',
#   'good',
#   'delivered',
#   'earlier',
#   'we',
#   'need',
#   'to',
#   'write',
#   'after',
#   'one',
#   'month',
#   'usage',
#   'over',
#   'all',
#   'this',
#   'product',
#   'is',
#   'good'],
#  ['nyc',
#   'product',
#   'value',
#   'for',
#   'money',
#   'thanks',
#   'flipcart',
#   'delivery',
#   'boy',
#   'behivour',
#   'was',
#   'veri',
#   'cool'],
#  ['v', 'nice'],
#  ['good', 'quality'],
#  ['good', 'one', 'induction', 'compatable'],
#  ['good', 'quality'],
#  ['we', 'can', 'make', 'sandwich'],
#  ['it', 'was', 'a', 'good', 'product', 'but', 'with', 'out', 'spoon'],
#  ['good'],
#  ['value',
#   'of',
#   'money',
#   'but',
#   'coating',
#   'is',
#   'not',
#   'perfect',
#   'but',
#   'i',
#   'am',
#   'still',
#   'using',
#   'it',
#   'works',
#   'nicely',
#   'in',
#   'making',
#   'roti',
#   'and',
#   'dhosa'],
#  ['nice'],
#  ['good', 'product'],
#  ['it',
#   'was',
#   'working',
#   'perfectly',
#   'on',
#   'stove',
#   'it',
#   'was',
#   'very',
#   'bug',
#   'size',
#   'and',
#   'very',
#   'good',
#   'quality',
#   'ceramic',
#   'coating',
#   'was',
#   'very',
#   'good',
#   'dont',
#   'think',
#   'about',
#   'negative',
#   'reviews',
#   'it',
#   'was',
#   'really',
#   'worths',
#   'for',
#   'the',
#   'money'],
#  ['good', 'product', 'value', 'of', 'money', 'must', 'buy'],
#  ['good', 'ok', 'for', 'the', 'price'],
#  ['awesome'],
#  ['super'],
#  ['vry', 'nys', 'im', 'vry', 'happy', 'thnx', 'flipcrt'],
#  ['good', 'product'],
#  ['good'],
#  ['nice', 'super'],
#  ['good', 'perfect', 'choice'],
#  ['awesome',
#   'product',
#   'on',
#   'this',
#   'price',
#   'delivery',
#   'boy',
#   'was',
#   'really',
#   'good'],
#  ['it', 's', 'nice', 'product', 'i', 'loved', 'it'],
#  ['excellent', 'product', 'must', 'go', 'for', 'it'],
#  ['nice', 'product'],
#  ['good', 'can', 'buy'],
#  ['perfect', 'premium', 'quality', 'build', 'product'],
#  ['the', 'non', 'stick', 'has', 'gone'],
#  ['good', 'one', 'i', 'love', 'it'],
#  ['not', 'bad'],
#  ['very', 'good', 'prodat'],
#  ['perfect'],
#  ['good',
#   'quality',
#   'weight',
#   'thiknes',
#   'value',
#   'for',
#   'money',
#   'thanks',
#   'for',
#   'giving',
#   'to',
#   'good',
#   'products',
#   'thanks',
#   'for',
#   'flipkart'],
#  ['good', 'quality'],
#  ['super'],
#  ['good'],
#  ['very', 'good', 'product'],
#  ['super', 'quality'],
#  ['good', 'product'],
#  ['it', 'is', 'nice', 'as', 'shown'],
#  ['good'],
#  ['good'],
#  ['nice', 'loved', 'it'],
#  ['value',
#   'for',
#   'money',
#   'product',
#   'thanx',
#   'let',
#   'me',
#   'write',
#   'more',
#   'details',
#   'after',
#   'a',
#   'month',
#   'now',
#   'am',
#   'satisfied',
#   'with',
#   'this',
#   'product'],
#  ['good'],
#  ['this', 'is', 'a', 'good', 'product', 'go', 'for', 'it'],
#  ['is', 'not', 'good', 'i', 'am', 'very', 'sad'],
#  ['nice', 'product'],
#  ['worth', 'it'],
#  ['very', 'well', 'dosa', 'tawa'],
#  ['value', 'for', 'money', 'ok'],
#  ['nice'],
#  ['very', 'interesting', 'product'],
#  ['very', 'nice', 'and', 'kind', 'behaviour', 'of', 'delivery', 'man'],
#  ['best', 'product', 'and', 'best', 'service'],
#  ['v', 'good'],
#  ['nice', 'product'],
#  ['very', 'good', 'to', 'use', 'in', 'low', 'cost'],
#  ['nice'],
#  ['good', 'product', 'amazing'],
#  ['nice'],
#  ['super', 'product'],
#  ['nice', 'product'],
#  ['good', 'product'],
#  ['good'],
#  ['very', 'nice', 'at', 'cheap', 'price'],
#  ['good'],
#  ['nice'],
#  ['good', 'product', 'and', 'good', 'delivery'],
#  ['nice'],
#  ['very', 'good'],
#  ['good', 'quality'],
#  ['worth', 'product', 'nice', 'quality', 'thkuu', 'flipkart'],
#  ['very', 'good', 'product'],
#  ['super'],
#  ['nice', 'product'],
#  ['good'],
#  ['nice'],
#  ['very', 'nice', 'product', 'and', 'affordable', 'price', 'looking', 'good'],
#  ['nice'],
#  ['ok', 'good'],
#  ['good'],
#  ['super', 'quality', 'awesome'],
#  ['good', 'product', 'for', 'the', 'price', 'paid'],
#  ['no', 'handel', 'included'],
#  ['coating', 'was', 'not', 'good'],
#  ['good', 'product', 'i', 'loved', 'it'],
#  ['good', 'quality'],
#  ['good'],
#  ['good'],
#  ['good'],
#  ['it', 's', 'really', 'too', 'gud', 'product'],
#  ['good'],
#  ['gud', 'product'],
#  ['good', 'product'],
#  ['good', 'product', 'and', 'value', 'for', 'money'],
#  ['nice', 'quality'],
#  ['value', 'for', 'money'],
#  ['good'],
#  ['good', 'product'],
#  ['i',
#   'like',
#   'this',
#   'product',
#   'its',
#   'very',
#   'good',
#   'quality',
#   'also',
#   'good'],
#  ['best',
#   'in',
#   'this',
#   'price',
#   'quality',
#   'i',
#   'don',
#   't',
#   'know',
#   'till',
#   'now',
#   'i',
#   'didn',
#   't',
#   'used'],
#  ['nice'],
#  ['super'],
#  ['good'],
#  ['good', 'product', 'my', 'mom', 's', 'favourite'],
#  ['it', 'good'],
#  ['good', 'product'],
#  ['gud'],
#  ['nice'],
#  ['awesome', 'fantastic'],
#  ['good', 'product'],
#  ['value', 'for', 'money'],
#  ['super', 'product'],
#  ['good'],
#  ['good'],
#  ['not', 'bad'],
#  ['it', 'is', 'for', 'induction', 'purpose', 'not', 'good', 'for', 'gas'],
#  ['not', 'bad', 'but', 'jast', 'ok'],
#  ['it', 's', 'amazing'],
#  ['very', 'good', 'product'],
#  ['very', 'good', 'and', 'affordable', 'price'],
#  ['good'],
#  ['good', 'products'],
#  ['good'],
#  ['blockbuster'],
#  ['value',
#   'for',
#   'money',
#   'very',
#   'nice',
#   'product',
#   'very',
#   'thank',
#   'you',
#   'flipkart'],
#  ['excellent'],
#  ['it',
#   's',
#   'a',
#   'nice',
#   'one',
#   'and',
#   'affordable',
#   'compare',
#   'with',
#   'branded',
#   'one',
#   'so',
#   'just',
#   'go',
#   'for',
#   'it',
#   'guys'],
#  ['material', 'is', 'good'],
#  ['best', 'product', 'and', 'best', 'service'],
#  ['worth'],
#  ['very', 'gud', 'product'],
#  ['quality', 'is', 'very', 'nicethank', 'you', 'flipkart'],
#  ['best', 'non', 'induction', 'tawa'],
#  ['it', 's', 'too', 'good'],
#  ['good', 'product', 'and', 'good', 'quality'],
#  ['nice', 'product', 'coating', 'and', 'size', 'is', 'good'],
#  ['induction',
#   'based',
#   'should',
#   'be',
#   'little',
#   'better',
#   'overall',
#   'tawa',
#   'and',
#   'it',
#   's',
#   'size',
#   'is',
#   'ok'],
#  ['excellent', 'product', 'tq', 'filpkart'],
#  ['super', 'pan'],
#  ['best', 'quality', 'product'],
#  ['product', 'not', 'a', 'best', 'its', 'a', 'average', 'product'],
#  ['super'],
#  ['overall', 'good'],
#  ['very', 'nice'],
#  ['good'],
#  ['ok'],
#  ['super',
#   'good',
#   'quality',
#   'and',
#   'good',
#   'design',
#   'thanks',
#   'for',
#   'flipkart'],
#  ['perfect',
#   'and',
#   'perfect',
#   'for',
#   'the',
#   'kitchen',
#   'and',
#   'delivery',
#   'is',
#   'also',
#   'fast'],
#  ['good', 'product'],
#  ['to', 'good'],
#  ['nice', 'tawa'],
#  ['very', 'good', 'product'],
#  ['good'],
#  ['very', 'nice'],
#  ['it', 's', 'good'],
#  ['very', 'good', 'product'],
#  ['really', 'good', 'product'],
#  ['amazing',
#   'product',
#   'i',
#   'am',
#   'in',
#   'love',
#   'the',
#   'quality',
#   'the',
#   'price',
#   'just',
#   'worth',
#   'it',
#   'highly',
#   'recommended'],
#  ['good'],
#  ['good'],
#  ['nice', 'product'],
#  ['nice'],
#  ['nice'],
#  ['average', 'product'],
#  ['gud', 'product'],
#  ['good'],
#  ['awesome'],
#  ['osm'],
#  ['ohk'],
#  ['ok'],
#  ['product',
#   'quality',
#   'is',
#   'not',
#   'very',
#   'good',
#   'but',
#   'overall',
#   'product',
#   'is',
#   'very',
#   'good',
#   'product',
#   'qualities',
#   'best'],
#  ['value', 'for', 'money', 'not', 'that', 'much', 'specifications'],
#  ['good', 'product', 'value', 'for', 'money'],
#  ['good', 'product', 'thanks'],
#  ['best', 'product'],
#  ['handle',
#   'broken',
#   'within',
#   'a',
#   'day',
#   'other',
#   'than',
#   'that',
#   'okay',
#   'worth',
#   'for',
#   'money'],
#  ['it', 'is', 'super', 'product'],
#  ['its', 'good'],
#  ['good'],
#  ['nice'],
#  ['nice'],
#  ['very', 'nice'],
#  ['nice'],
#  ['nice', 'products'],
#  ['value', 'of', 'money'],
#  ['just', 'ok', 'tq', 'fc'],
#  ['good'],
#  ['good', 'go', 'for', 'it', 'guys'],
#  ['good', 'product', 'worth', 'buying'],
#  ['nice', 'product'],
#  ['good', 'quality'],
#  ['nice'],
#  ['cost', 'effective'],
#  ['superb'],
#  ['best', 'quality', 'worth', 'for', 'money', 'thank', 'you', 'flipkart'],
#  ['good', 'product'],
#  ['nice', 'an', 'good', 'condition', 'recive', 'd'],
#  ['vry', 'nice'],
#  ['money', 'worth'],
#  ['good', 'product'],
#  ['product', 'small', 'size', 'average', 'item'],
#  ['value', 'for', 'money'],
#  ['not', 'bad', 'average'],
#  ['good'],
#  ['goodone'],
#  ['nice'],
#  ['its',
#   'good',
#   'quality',
#   'nice',
#   'but',
#   'its',
#   'niot',
#   'so',
#   'big',
#   'but',
#   'valueble',
#   'for',
#   'money'],
#  ['good'],
#  ['good', 'product'],
#  ['awesome',
#   'i',
#   've',
#   'been',
#   'using',
#   'this',
#   'tawa',
#   'for',
#   'a',
#   'week',
#   'and',
#   'it',
#   's',
#   'truly',
#   'excellent',
#   'i',
#   'retired',
#   'my',
#   'old',
#   'non',
#   'stick',
#   'the',
#   'moment',
#   'this',
#   'arrived',
#   'and',
#   'for',
#   'a',
#   'week',
#   'i',
#   've',
#   'used',
#   'it',
#   'for',
#   'dosas',
#   'and',
#   'they',
#   'come',
#   'out',
#   'neatly',
#   'without',
#   'effort',
#   'even',
#   'with',
#   'minimal',
#   'oil',
#   'i',
#   'logged',
#   'in',
#   'to',
#   'flipkart',
#   'today',
#   'to',
#   'order',
#   'another',
#   'one',
#   'for',
#   'frying',
#   'eggs',
#   'but',
#   'found',
#   'it',
#   's',
#   'not',
#   'in',
#   'stock',
#   'will',
#   'get',
#   'a',
#   'nd',
#   'one',
#   'whenever',
#   'it',
#   's',
#   'available',
#   'next'],
#  ['excellent'],
#  ['good', 'quality', 'product'],
#  ['good'],
#  ['value', 'for', 'money', 'product'],
#  ['awesome', 'must', 'buy', 'it'],
#  ['fantastic', 'product', 'up', 'to', 'the', 'mark'],
#  ['nice', 'one'],
#  ['most', 'beautiful', 'and', 'good', 'product'],
#  ['nice'],
#  ['very', 'good', 'product'],
#  ['good'],
#  ['nice', 'product'],
#  ['the',
#   'tawa',
#   'is',
#   'so',
#   'strong',
#   'and',
#   'nice',
#   'design',
#   'but',
#   'it',
#   'could',
#   'have',
#   'been',
#   'included',
#   'a',
#   'wood',
#   'spoon',
#   'along',
#   'with',
#   'the',
#   'tawa'],
#  ['anwsome', 'product'],
#  ['good',
#   'one',
#   'as',
#   'expected',
#   'its',
#   'my',
#   'second',
#   'purchase',
#   'of',
#   'this',
#   'tawa',
#   'its',
#   'really',
#   'nice',
#   'now',
#   'our',
#   'family',
#   'and',
#   'grand',
#   'parents',
#   'family',
#   'are',
#   'using',
#   'this'],
#  ['very', 'nice', 'product'],
#  ['very',
#   'nice',
#   'product',
#   'customer',
#   'is',
#   'very',
#   'happy',
#   'thanks',
#   'flipkart',
#   'excellent'],
#  ['nice'],
#  ['nice', 'product'],
#  ['good'],
#  ['osm', 'i', 'just', 'love', 'it', 'thank', 'you', 'flipkart'],
#  ['very', 'good', 'product'],
#  ['good'],
#  ['nice'],
#  ['very', 'good'],
#  ['good', 'quality', 'pan', 'recommended'],
#  ['good'],
#  ['super', 'super', 'good'],
#  ['good'],
#  ['good'],
#  ['nice', 'product'],
#  ['good', 'fenising'],
#  ['very', 'good', 'must', 'buy'],
#  ['super'],
#  ['best'],
#  ['quality', 'is', 'not', 'so', 'good'],
#  ['this',
#   'is',
#   'good',
#   'product',
#   'and',
#   'its',
#   'switable',
#   'both',
#   'induction',
#   'and',
#   'gas',
#   'value',
#   'for',
#   'money'],
#  ['good', 'quality'],
#  ['excellent',
#   'non',
#   'stick',
#   'tawa',
#   'no',
#   'issue',
#   'with',
#   'flipping',
#   'omelette',
#   'and',
#   'south',
#   'indian',
#   'cuisine',
#   'that',
#   'too',
#   'require',
#   'least',
#   'oil',
#   'consumption',
#   'left',
#   'no',
#   'burning',
#   'after',
#   'taste',
#   'even',
#   'when',
#   'overcooked'],
#  ['it', 'is', 'a', 'ok', 'product', 'not', 'so', 'good'],
#  ['nice', 'but', 'not', 'satisfied'],
#  ['ok'],
#  ['nice', 'products'],
#  ['nice', 'product', 'value', 'for', 'money'],
#  ['nice', 'product'],
#  ['good', 'product'],
#  ['love', 'this', 'product', 'go', 'for', 'it'],
#  ['i',
#   'recommend',
#   'every',
#   'one',
#   'to',
#   'buy',
#   'this',
#   'product',
#   'i',
#   'love',
#   'flipkart'],
#  ['overall', 'nice', 'at', 'the', 'price', 'range'],
#  ['very', 'good'],
#  ['nice', 'product'],
#  ['good'],
#  ['to', 'good'],
#  ['good', 'product', 'very', 'nice', 'money', 'for', 'value'],
#  ['osm', 'product'],
#  ['super', 'but', 'all', 'induction', 'is', 'not', 'work'],
#  ['good'],
#  ['excellent', 'product'],
#  ['good'],
#  ['good', 'product'],
#  ['super', 'nice'],
#  ['value',
#   'for',
#   'money',
#   'non',
#   'sticky',
#   'pan',
#   'is',
#   'very',
#   'good',
#   'used',
#   'to',
#   'make',
#   'dosa'],
#  ['good', 'product', 'and', 'good', 'delivery'],
#  ['it',
#   's',
#   's',
#   'nice',
#   'product',
#   'according',
#   'to',
#   'the',
#   'price',
#   'range'],
#  ['material', 'quality', 'is', 'very', 'good', 'thank', 'you', 'flip', 'kart'],
#  ['outstanding'],
#  ['very', 'good', 'product'],
#  ['good', 'product'],
#  ['good'],
#  ['average',
#   'quality',
#   'product',
#   'the',
#   'handle',
#   'of',
#   'the',
#   'tawa',
#   'got',
#   'loose',
#   'after',
#   'second',
#   'use',
#   'only'],
#  ['super', 'product', 'very', 'strong', 'tqq', 'soo', 'much', 'flipkart'],
#  ['value', 'for', 'money'],
#  ['good', 'product'],
#  ['so', 'good', 'and', 'affordable', 'in', 'rs'],
#  ['nice'],
#  ['nice', 'product'],
#  ['value', 'for', 'money', 'product'],
#  ['i', 'like', 'so', 'good', 'product'],
#  ['value', 'of', 'money'],
#  ['good', 'product'],
#  ['nice', 'product'],
#  ['nice', 'one'],
#  ['good', 'but', 'skrup', 'ar', 'not', 'their'],
#  ['gud', 'product'],
#  ['good'],
#  ['good', 'product'],
#  ['value', 'of', 'money'],
#  ['size',
#   'is',
#   'cm',
#   'lesser',
#   'than',
#   'what',
#   'mentioned',
#   'overall',
#   'value',
#   'for',
#   'money',
#   'at',
#   'this',
#   'price',
#   'point'],
#  ['very', 'nice'],
#  ['good'],
#  ['good', 'productmust', 'buy'],
#  ['excellent', 'pan'],
#  ['best', 'quality'],
#  ['ok', 'nice'],
#  ['good', 'product'],
#  ['excellent', 'product', 'worth', 'itmust', 'buy'],
#  ['super'],
#  ['ok', 'material'],
#  ['thank',
#   'you',
#   'flipkart',
#   'nice',
#   'product',
#   'highly',
#   'recommend',
#   'this',
#   'item'],
#  ['good', 'product', 'i', 'like', 'it'],
#  ['nice'],
#  ['thanks'],
#  ['very', 'nice', 'product'],
#  ['nice',
#   'product',
#   'size',
#   'is',
#   'also',
#   'big',
#   'looks',
#   'wise',
#   'great',
#   'quality',
#   'good',
#   'but',
#   'difficult',
#   'to',
#   'cook',
#   'on',
#   'heater',
#   'useful',
#   'for',
#   'gas',
#   'overall',
#   'a',
#   'decent',
#   'product'],
#  ['good', 'quality'],
#  ['good', 'product'],
#  ['good', 'product', 'small', 'size', 'good', 'design'],
#  ['good', 'product'],
#  ['thnks', 'flipcart'],
#  ['nice'],
#  ['good', 'product', 'happy', 'for', 'buying'],
#  ['good'],
#  ['very', 'nice'],
#  ['good', 'product', 'but', 'handel', 'is', 'loose'],
#  ['good',
#   'for',
#   'making',
#   'non',
#   'sticky',
#   'foods',
#   'i',
#   'have',
#   'maked',
#   'of',
#   'it',
#   'that',
#   'was',
#   'very',
#   'nice'],
#  ['good'],
#  ['good'],
#  ['very',
#   'nice',
#   'product',
#   'good',
#   'quality',
#   'value',
#   'worthy',
#   'must',
#   'have',
#   'in',
#   'the',
#   'kitchen',
#   'thank',
#   'you',
#   'flipcart'],
#  ['good'],
#  ['very', 'nice'],
#  ['good', 'product'],
#  ['good', 'product'],
#  ['ok'],
#  ['very', 'nice'],
#  ['marvallous',
#   'product',
#   'under',
#   'budget',
#   'suitable',
#   'for',
#   'electric',
#   'induction',
#   'non',
#   'stick',
#   'coting',
#   'is',
#   'good',
#   'usefull',
#   'for',
#   'dosa',
#   'and',
#   'chapati',
#   'making',
#   'thanks',
#   'to',
#   'dealer'],
#  ['gud'],
#  ['very', 'good', 'product'],
#  ['nice'],
#  ['good'],
#  ['very', 'nice'],
#  ['super'],
#  ['quality',
#   'is',
#   'superb',
#   'excellent',
#   'product',
#   'in',
#   'this',
#   'reasonable',
#   'price',
#   'thank',
#   'u',
#   'flipkart'],
#  ['good',
#   'product',
#   'in',
#   'this',
#   'price',
#   'thanks',
#   'to',
#   'delivery',
#   'boy',
#   'and',
#   'flipkart',
#   'also'],
#  ['very', 'nice', 'product', 'quality', 'satisfied', 'easy', 'to', 'use'],
#  ['very', 'nice'],
#  ['good'],
#  ['best'],
#  ['good', 'product', 'value', 'of', 'money'],
#  ['good'],
#  ['good', 'product', 'flipkartquality', 'namber', 'best', 'dewl'],
#  ['this', 'good', 'but', 'handel', 'is', 'not', 'very', 'mutch'],
#  ['good', 'one'],
#  ['good', 'product', 'delivery', 'boy', 'is', 'very', 'rude'],
#  ['nice', 'good'],
#  ['excellent'],
#  ['must', 'buy'],
#  ['good'],
#  ['nice', 'product'],
#  ['nice', 'product'],
#  ['good'],
#  ['just', 'ok'],
#  ['supper'],
#  ['very', 'nice', 'helpful'],
#  ['good', 'product', 'must', 'buy', 'it'],
#  ['good', 'product'],
#  ['value', 'for', 'money'],
#  ['really', 'nice', 'good', 'product', 'looking', 'great'],
#  ['very',
#   'good',
#   'quality',
#   'coating',
#   'is',
#   'very',
#   'nice',
#   'bigger',
#   'then',
#   'i',
#   'expectvalue',
#   'for',
#   'moneymust',
#   'buy'],
#  ['very', 'good'],
#  ['i', 'loved', 'it'],
#  ['nice', 'product'],
#  ['nice'],
#  ['wow', 'nice', 'product', 'thank', 'you', 'flipkart'],
#  ['super'],
#  ['best', 'product', 'tq', 'flip', 'cart'],
#  ['it', 's', 'item', 'is', 'very', 'nice'],
#  ['good'],
#  ['good'],
#  ['wonderful'],
#  ['good', 'product'],
#  ['nice', 'product', 'up', 'to', 'mark'],
#  ['good', 'product'],
#  ['nice'],
#  ['good', 'value', 'for', 'money'],
#  ['very', 'good', 'product', 'and', 'price'],
#  ['nice'],
#  ['very',
#   'good',
#   'product',
#   'i',
#   'exempting',
#   'more',
#   'more',
#   'better',
#   'packing',
#   'is',
#   'good',
#   'tku',
#   'flipcart'],
#  ['very', 'nice', 'product', 'go', 'for', 'it'],
#  ['good'],
#  ['mind', 'blowing'],
#  ['gud', 'one'],
#  ['gud', 'product'],
#  ['good', 'quality', 'with', 'looking'],
#  ['good', 'quality'],
#  ['best'],
#  ['nice'],
#  ['average'],
#  ['nice', 'you', 'can', 'buy'],
#  ['exlent', 'product'],
#  ['just', 'awesome', 'with', 'affordable', 'price', 'value', 'for', 'money'],
#  ['thats', 'so', 'nice', 'and', 'it', 'looks', 'good', 'go', 'for', 'it'],
#  ['nice',
#   'dosa',
#   'tava',
#   'but',
#   'i',
#   'am',
#   'very',
#   'disappointed',
#   'from',
#   'coating',
#   'in',
#   'back',
#   'side',
#   'is',
#   'gone',
#   'when',
#   'making',
#   'dosa',
#   'and',
#   'it',
#   'is',
#   'not',
#   'isi',
#   'certified'],
#  ['must', 'by'],
#  ['nice', 'finish', 'and', 'value', 'for', 'money', 'product'],
#  ['value', 'for', 'money'],
#  ['good', 'product'],
#  ['best',
#   'product',
#   'by',
#   'master',
#   'making',
#   'dosa',
#   'are',
#   'excellent',
#   'thin',
#   'crispy'],
#  ['nice', 'pan'],
#  ['average'],
#  ['very', 'very', 'good'],
#  ['good'],
#  ['best',
#   'in',
#   'the',
#   'market',
#   'thanks',
#   'for',
#   'flipkart',
#   'and',
#   'delivery',
#   'boy'],
#  ['nice', 'quality'],
#  ['nice'],
#  ['compair', 'to', 'cost', 'tawa', 'is', 'excellent'],
#  ['very', 'well', 'dosa', 'tawa'],
#  ['good'],
#  ['i', 'am', 'so', 'happy'],
#  ['nice'],
#  ['best', 'hai'],
#  ['overall', 'good'],
#  ['really', 'god', 'product', 'satisfied'],
#  ['very', 'nice', 'product'],
#  ['tawa', 'quality', 'good'],
#  ['avrage'],
#  ['nice'],
#  ['mass'],
#  ['good'],
#  ['good', 'product'],
#  ['awesome'],
#  ['valuable', 'money'],
#  ['really', 'good', 'choice', 'go', 'for', 'it'],
#  ['price', 'and', 'quality', 'best', 'combination', 'good', 'product', 'nice'],
#  ['very', 'good'],
#  ['everything',
#   'is',
#   'good',
#   'in',
#   'this',
#   'price',
#   'but',
#   'handle',
#   'is',
#   'cheap',
#   'and',
#   'not',
#   'dureble'],
#  ['good', 'one'],
#  ['good', 'but', 'the', 'back', 'cover', 'will', 'bad'],
#  ['super', 'product'],
#  ['good', 'product'],
#  ['i',
#   'liked',
#   'this',
#   'product',
#   'very',
#   'much',
#   'it',
#   'is',
#   'strong',
#   'hence',
#   'a',
#   'little',
#   'heavy',
#   'size',
#   'is',
#   'big',
#   'which',
#   'i',
#   'required',
#   'perfect',
#   'for',
#   'dosa',
#   'omelette',
#   'didn',
#   't',
#   'use',
#   'it',
#   'on',
#   'induction',
#   'but',
#   'it',
#   'seems',
#   'it',
#   'will',
#   'easily',
#   'work',
#   'on',
#   'that',
#   'too',
#   'just',
#   'loved',
#   'the',
#   'product'],
#  ['spr'],
#  ['nice', 'thanks', 'flipkart', 'best', 'in', 'the', 'market'],
#  ['so', 'good', 'product'],
#  ['very', 'nice'],
#  ['value', 'for', 'money'],
#  ['too', 'good', 'thnk', 'u', 'flipkart'],
#  ['good', 'very', 'good'],
#  ['it', 'is', 'bad', 'products'],
#  ['very', 'good'],
#  ['super'],
#  ['mother',
#   's',
#   'been',
#   'using',
#   'the',
#   'pan',
#   'from',
#   'last',
#   'days',
#   'or',
#   'so',
#   'and',
#   'it',
#   's',
#   'been',
#   'brilliant',
#   'so',
#   'far',
#   'no',
#   'issues',
#   'none',
#   'so',
#   'far',
#   'will',
#   'update',
#   'more',
#   'as',
#   'time',
#   'passes'],
#  ['ok'],
#  ['nce'],
#  ['super'],
#  ['good'],
#  ['satisfied', 'purchase'],
#  ['good'],
#  ['very', 'nice', 'product'],
#  ['nice', 'product', 'loved', 'it'],
#  ['brought',
#   'it',
#   'for',
#   'the',
#   'induction',
#   'stove',
#   'but',
#   'its',
#   'not',
#   'suitable',
#   'for',
#   'the',
#   'induction'],
#  ['it', 's', 'awesome'],
#  ['good'],
#  ['nice', 'prodcet'],
#  ['osm'],
#  ['useful', 'tawa'],
#  ['good'],
#  ['very', 'good', 'easy', 'handling', 'which', 'one', 'they', 'best'],
#  ['very', 'good', 'product', 'i', 'like', 'it', 'very', 'very', 'much'],
#  ['nice'],
#  ['nice'],
#  ['very', 'nice'],
#  ['god'],
#  ['good', 'quality'],
#  ['very', 'nice'],
#  ['good', 'product'],
#  ['good'],
#  ['good', 'quality', 'and', 'value', 'for', 'money'],
#  ['super'],
#  ['good', 'big', 'size'],
#  ['at',
#   'least',
#   'they',
#   'should',
#   'provide',
#   'even',
#   'a',
#   'wooden',
#   'spoon',
#   'along',
#   'with',
#   'it'],
#  ['the',
#   'pan',
#   'is',
#   'good',
#   'and',
#   'non',
#   'sticky',
#   'comfortable',
#   'and',
#   'light',
#   'weight',
#   'used',
#   'it',
#   'for',
#   'making',
#   'dosa',
#   'and',
#   'chilla',
#   'good'],
#  ['bad', 'quality'],
#  ['nice', 'product'],
#  ['not', 'soo', 'good', 'quality', 'but', 'ok', 'in', 'price'],
#  ['ok', 'ok'],
#  ['delivery', 'man', 'is', 'also', 'good'],
#  ['nice'],
#  ['it', 'was', 'nice', 'product'],
#  ['my',
#   'sister',
#   'is',
#   'verry',
#   'happy',
#   'thish',
#   'pruduct',
#   'verry',
#   'good',
#   'pruduct'],
#  ['good', 'product'],
#  ['nice', 'acha', 'ha', 'es', 'price', 'ma'],
#  ['osm'],
#  ['we', 'can', 'blindly', 'buy', 'this', 'tawa', 'specially', 'for', 'dosha'],
#  ['very', 'good'],
#  ['is',
#   'good',
#   'looking',
#   'nicely',
#   'working',
#   'on',
#   'induction',
#   'and',
#   'gas'],
#  ['good',
#   'at',
#   'this',
#   'price',
#   'but',
#   'colour',
#   'started',
#   'coming',
#   'out',
#   'only',
#   'in',
#   'use'],
#  ['just', 'ok'],
#  ['good'],
#  ['good', 'product', 'must', 'buy', 'it'],
#  ['good'],
#  ['for', 'cheap', 'price', 'you', 'are', 'getting', 'a', 'good', 'pan'],
#  ['super'],
#  ['good', 'quality'],
#  ['nice', 'product'],
#  ['i',
#   'purchased',
#   'it',
#   'in',
#   'offers',
#   'it',
#   's',
#   'very',
#   'nice',
#   'in',
#   'size',
#   'and',
#   'quality',
#   'also',
#   'thankyou',
#   'flipkart'],
#  ['good'],
#  ['it', 's', 'a', 'good', 'product', 'at', 'this', 'price'],
#  ['you', 'should', 'buy', 'this', 'tawa'],
#  ['good'],
#  ['super'],
#  ['amazing', 'product', 'good', 'quality'],
#  ['good', 'product'],
#  ['good', 'master', 'good', 'quality', 'dosa', 'tawa', 'cm', 'good'],
#  ['nice'],
#  ['nice', 'product', 'u', 'can', 'byu', 'it', 'frds'],
#  ['very', 'nice', 'excellent', 'products'],
#  ['good', 'product'],
#  ['vary', 'good'],
#  ['good', 'product'],
#  ['good'],
#  ['very', 'big', 'size', 'i', 'like', 'it', 'so', 'much', 'super'],
#  ['good'],
#  ['its', 'good', 'value', 'for', 'money', 'product'],
#  ['good', 'it', 's', 'nice', 'to', 'see'],
#  ['ok', 'type'],
#  ['ok'],
#  ['good'],
#  ['good', 'product', 'for', 'kitchen'],
#  ['good', 'product'],
#  ['very', 'nice', 'quality'],
#  ['good', 'ok'],
#  ['very', 'nice', 'product'],
#  ['very', 'nice', 'product', 'value', 'for', 'money'],
#  ['good'],
#  ['awesome', 'correct', 'size', 'and', 'good', 'plating'],
#  ['supet'],
#  ['worth', 'it'],
#  ['good', 'quality'],
#  ['nice'],
#  ['good', 'enough'],
#  ['very', 'nice', 'product', 'thank', 'you', 'flipkart'],
#  ['nice'],
#  ['nice', 'product'],
#  ['nice', 'quality'],
#  ['nice', 'product'],
#  ['nice', 'product'],
#  ['nice'],
#  ['value', 'for', 'money'],
#  ['super'],
#  ['very', 'nice'],
#  ['super'],
#  ['buy', 'product', 'is', 'good'],
#  ['pan', 'handle', 'is', 'not', 'getting', 'tight'],
#  ['good'],
#  ['good'],
#  ['good'],
#  ['not', 'bad', 'avarage'],
#  ['super'],
#  ['its',
#   'ok',
#   'but',
#   'the',
#   'middle',
#   'area',
#   'is',
#   'high',
#   'like',
#   'oval',
#   'type',
#   'so',
#   'that',
#   'when',
#   'you',
#   'pour',
#   'oil',
#   'the',
#   'oil',
#   'flows',
#   'to',
#   'side',
#   'area',
#   'but',
#   'its',
#   'ok',
#   'to',
#   'make',
#   'dry',
#   'roti'],
#  ['nice'],
#  ['this',
#   'product',
#   'is',
#   'amazing',
#   'and',
#   'value',
#   'for',
#   'money',
#   'can',
#   'i',
#   'use',
#   'it',
#   'on',
#   'induction',
#   'stove'],
#  ['good'],
#  ['usefull', 'product'],
#  ['good'],
#  ['quality',
#   'is',
#   'very',
#   'bad',
#   'of',
#   'this',
#   'tava',
#   'paint',
#   'has',
#   'gone',
#   'after',
#   'st',
#   'use'],
#  ['product',
#   'it',
#   's',
#   'amazing',
#   'and',
#   'good',
#   'coating',
#   'valu',
#   'for',
#   'money',
#   'but',
#   'i',
#   'm',
#   'not',
#   'satisfied',
#   'on',
#   'flipkart',
#   'because',
#   'my',
#   'order',
#   'is',
#   'delayed',
#   'without',
#   'any',
#   'reason',
#   'so',
#   'please',
#   'flipkart',
#   'team',
#   'this',
#   'problem',
#   'fix',
#   'it',
#   'thank',
#   'you'],
#  ['good', 'quality'],
#  ['good'],
#  ['nice', 'tawa', 'but', 'the', 'color', 'have', 'started', 'disappearing'],
#  ['very', 'nice', 'product', 'easy', 'to', 'make', 'a', 'dosa', 'faster'],
#  ['nice', 'product'],
#  ['nice', 'products'],
#  ['good', 'quality', 'and', 'delivery', 'good'],
#  ['very', 'good'],
#  ['low', 'price', 'good', 'quality'],
#  ['good'],
#  ['supper', 'products'],
#  ['nice', 'product'],
#  ['nice', 'product'],
#  ['nyc'],
#  ['good'],
#  ['good'],
#  ['average'],
#  ['good', 'going'],
#  ['gud'],
#  ['perfect', 'is', 'perfect', 'master'],
#  ['naic'],
#  ['nyc', 'nyc'],
#  ['value', 'for', 'money'],
#  ['very',
#   'nice',
#   'products',
#   'first',
#   'time',
#   'oder',
#   'the',
#   'flipkart',
#   'good',
#   'experience'],
#  ['very', 'good'],
#  ['super'],
#  ['after',
#   'using',
#   'for',
#   'months',
#   'i',
#   'm',
#   'writing',
#   'this',
#   'review',
#   'i',
#   'dnt',
#   'like',
#   'it',
#   's',
#   'quality',
#   'totally',
#   'pathetic',
#   'product'],
#  ['big', 'tawa', 'and', 'superb', 'coating'],
#  ['good'],
#  ['good'],
#  ['excellent'],
#  ['very', 'good'],
#  ['super',
#   'quality',
#   'tq',
#   'first',
#   'time',
#   'delivery',
#   'chesam',
#   'ilove',
#   'this',
#   'product'],
#  ['really',
#   'value',
#   'of',
#   'money',
#   'best',
#   'quality',
#   'and',
#   'biggest',
#   'size',
#   'thank',
#   'you',
#   'flipkart'],
#  ['good'],
#  ['good', 'product'],
#  ['nice'],
#  ['good', 'product'],
#  ['mind',
#   'blowing',
#   'product',
#   'i',
#   'love',
#   'it',
#   'thank',
#   'you',
#   'flipkart',
#   'and',
#   'his',
#   'team'],
#  ['very', 'good', 'product'],
#  ['nice', 'god', 'quality'],
#  ['quality', 'is', 'average'],
#  ['batane', 'big', 'size', 'cm', 'barhaye', 'but', 'small', 'size', 'aya'],
#  ['awesome', 'product'],
#  ['nice', 'purchase'],
#  ['nice', 'product'],
#  ['good', 'one'],
#  ['good', 'not', 'very', 'good'],
#  ['perfect', 'for', 'induction'],
#  ['super', 'hai', 'excellent'],
#  ['i', 'don', 't', 'like'],
#  ['very', 'good', 'and', 'big', 'size', 'nice', 'for', 'dosa'],
#  ['satisfied'],
#  ['super'],
#  ['it',
#   's',
#   'really',
#   'good',
#   'and',
#   'induction',
#   'based',
#   'also',
#   'fast',
#   'delivery',
#   'tnq',
#   'flipcart'],
#  ['the', 'product', 'is', 'good', 'liked', 'it', 'ok', 'for', 'daily', 'use'],
#  ['super', 'product'],
#  ['super', 'se', 'uper'],
#  ['just', 'for', 'it'],
#  ['very', 'nice', 'product'],
#  ['size', 'is', 'small', 'but', 'otherwise', 'an', 'good', 'product'],
#  ['good', 'quality'],
#  ['superb'],
#  ['good'],
#  ['i',
#   'am',
#   'very',
#   'happy',
#   'this',
#   'product',
#   'is',
#   'so',
#   'good',
#   'at',
#   'quality',
#   'and',
#   'also',
#   'in',
#   'design',
#   'and',
#   'finishing',
#   'thank',
#   'you',
#   'flipkart'],
#  ['nice', 'product', 'love', 'it'],
#  ['very', 'nice', 'tawa', 'thanks', 'flipkart'],
#  ['nice', 'product'],
#  ['good'],
#  ['very', 'good', 'quality', 'as', 'per', 'the', 'price', 'range'],
#  ['nyc'],
#  ['super'],
#  ['good', 'product'],
#  ['good', 'product'],
#  ['good', 'and', 'nice'],
#  ['nice'],
#  ['nice'],
#  ['nice'],
#  ['very', 'nice', 'quality', 'very', 'good'],
#  ['super', 'tava'],
#  ['nice', 'product'],
#  ['superb', 'al', 'must', 'go', 'for', 'it', 'worth', 'for', 'money'],
#  ['good'],
#  ['ok'],
#  ['good', 'product', 'but', 'can', 't', 'use', 'on', 'induction'],
#  ['good', 'product', 'i', 'liked'],
#  ['very',
#   'nice',
#   'product',
#   'we',
#   'can',
#   'make',
#   'very',
#   'large',
#   'dosa',
#   'without',
#   'sticking',
#   'really',
#   'awesome'],
#  ['nice'],
#  ['great', 'product'],
#  ['nice', 'product'],
#  ['good'],
#  ['good'],
#  ['super', 'product'],
#  ['good', 'product'],
#  ['amazing',
#   'tawa',
#   'thaks',
#   'flipkart',
#   'for',
#   'giving',
#   'such',
#   'a',
#   'nice',
#   'taw',
#   'a',
#   'for',
#   'less',
#   'price',
#   'worth',
#   'even',
#   'a',
#   'peny'],
#  ['light', 'weight', 'superb'],
#  ['good', 'quality'],
#  ['iam', 'fully', 'satisfied'],
#  ['i',
#   'have',
#   'not',
#   'get',
#   'wooden',
#   'spatula',
#   'inside',
#   'otherwise',
#   'it',
#   's',
#   'fine',
#   'tawa'],
#  ['ok', 'ok'],
#  ['nice'],
#  ['go', 'for', 'it', 'nice', 'product'],
#  ['nice', 'product'],
#  ['very', 'good', 'product', 'thanks'],
#  ['good', 'product'],
#  ['super', 'fixed', 'for', 'induction'],
#  ['just', 'ok'],
#  ['gud', 'but', 'tawa', 'back', 'side', 'colour', 'is', 'going'],
#  ['small', 'size'],
#  ['excellent', 'tawa', 'made', 'paneer', 'tikka', 'on', 'first', 'day'],
#  ['very', 'good'],
#  ['nice', 'for', 'this', 'much', 'price', 'thank', 'you', 'flipkart'],
#  ['gpod'],
#  ['good'],
#  ['it', 's', 'good'],
#  ['verry', 'nice'],
#  ['good'],
#  ['very', 'nice'],
#  ['very', 'good', 'product', 'thanks', 'kyu', 'flipkart'],
#  ['bast', 'product'],
#  ['good', 'products', 'go', 'for', 'it'],
#  ['ok', 'ok', 'prodeq', 'h'],
#  ['good', 'product'],
#  ['i', 'am', 'very', 'happy', 'thanks', 'flipkart'],
#  ['coating',
#   'is',
#   'good',
#   'on',
#   'top',
#   'however',
#   'at',
#   'the',
#   'bottom',
#   'the',
#   'paint',
#   'started',
#   'removing',
#   'due',
#   'to',
#   'scratches',
#   'from',
#   'gas',
#   'top',
#   'after',
#   'just',
#   'nd',
#   'time',
#   'usage',
#   'not',
#   'good'],
#  ['good', 'product'],
#  ['nice',
#   'design',
#   'i',
#   'feel',
#   'better',
#   'nice',
#   'product',
#   'thank',
#   'you',
#   'flipkart'],
#  ['nice', 'product', 'i', 'like', 'it'],
#  ['it', 's', 'good', 'but', 'very', 'thin', 'tawa'],
#  ['nice'],
#  ['really',
#   'very',
#   'nice',
#   'tawaa',
#   'wid',
#   'low',
#   'price',
#   'i',
#   'really',
#   'like',
#   'it'],
#  ['nice'],
#  ['handle', 'quality', 'is', 'average'],
#  ['excellent', 'product'],
#  ['good', 'one'],
#  ['thank', 'you', 'flipkart'],
#  ['good'],
#  ['good'],
#  ['good'],
#  ['nice', 'proudest'],
#  ['not',
#   'used',
#   'till',
#   'now',
#   'but',
#   'looking',
#   'vise',
#   'quality',
#   'was',
#   'good'],
#  ['oky'],
#  ['good', 'product', 'value', 'for', 'money'],
#  ['low', 'price', 'best', 'quality'],
#  ['dosa', 'pan', 'smooth'],
#  ['in', 'this', 'price', 'it', 's', 'too', 'good'],
#  ['good', 'product'],
#  ['ok'],
#  ['value', 'for', 'money'],
#  ['nice', 'product'],
#  ['very', 'nice', 'product', 'thanks'],
#  ['good'],
#  ['this',
#   'is',
#   'very',
#   'useful',
#   'product',
#   'for',
#   'me',
#   'i',
#   'have',
#   'been',
#   'using',
#   'it',
#   'since',
#   'year',
#   'and',
#   'this',
#   'is',
#   'today',
#   's',
#   'pic'],
#  ['super'],
#  ['become', 'a', 'useful', 'one', 'in', 'my', 'kitchen'],
#  ['good', 'product', 'go', 'for', 'it'],
#  ['awesome', 'tawa', 'at', 'price', 'range'],
#  ['not', 'bad'],
#  ['nice'],
#  ['good'],
#  ['realy', 'nice', 'product', 'thank', 'u', 'filp', 'cart'],
#  ['nice'],
#  ['nice', 'product'],
#  ['super'],
#  ['nice'],
#  ['cheap', 'n', 'best'],
#  ['build', 'quality', 'is', 'not', 'that', 'great', 'but', 'ok'],
#  ['good', 'material'],
#  ['it', 's', 'good', 'products'],
#  ['satisfied'],
#  ['very', 'good', 'product'],
#  ['best', 'design', 'and', 'good', 'quality'],
#  ['good', 'product'],
#  ['value', 'for', 'money'],
#  ['it', 's', 'amazing', 'tawa', 'on', 'time', 'delivery'],
#  ['quality',
#   'of',
#   'handle',
#   'is',
#   'not',
#   'that',
#   'much',
#   'good',
#   'and',
#   'handle',
#   'is',
#   'quiet',
#   'loose',
#   'apart',
#   'from',
#   'this',
#   'everything',
#   'looks',
#   'good'],
#  ['very', 'good', 'tawa', 'for', 'daily', 'used'],
#  ['good', 'product'],
#  ['nice', 'product'],
#  ['nice', 'product'],
#  ['good', 'quality'],
#  ['good', 'quality'],
#  ['excellent'],
#  ['super'],
#  ['good', 'product'],
#  ['awesome'],
#  ['super'],
#  ['super', 'quality'],
#  ['very', 'very', 'very', 'good', 'product'],
#  ['it', 's', 'good'],
#  ['good'],
#  ['good'],
#  ['good', 'one', 'satisfied'],
#  ['very',
#   'nice',
#   'producthigh',
#   'levelsop',
#   'product',
#   'by',
#   'flipkartmust',
#   'buy'],
#  ['good'],
#  ['good', 'quality'],
#  ['the',
#   'product',
#   'is',
#   'very',
#   'good',
#   'and',
#   'i',
#   'get',
#   'it',
#   'in',
#   'a',
#   'good',
#   'condition',
#   'by',
#   'a',
#   'good',
#   'delivery',
#   'excutive',
#   'or',
#   'boy'],
#  ['use', 'panna', 'super', 'ra', 'irukku'],
#  ['good'],
#  ['good',
#   'but',
#   'for',
#   'dosa',
#   'it',
#   's',
#   'too',
#   'small',
#   'for',
#   'south',
#   'indian',
#   'not',
#   'recommended'],
#  ['good', 'tawa', 'and', 'good', 'for', 'the', 'budget'],
#  ['good', 'product'],
#  ['good', 'product', 'loved', 'it'],
#  ['nice', 'one'],
#  ['very', 'good'],
#  ['tava',
#   'was',
#   'good',
#   'but',
#   'one',
#   'thing',
#   'which',
#   'disturbed',
#   'me',
#   'was',
#   'it',
#   's',
#   'quality',
#   'of',
#   'colour',
#   'it',
#   'got',
#   'fade',
#   'away',
#   'when',
#   'i',
#   'have',
#   'use',
#   'it',
#   'on',
#   'gas'],
#  ['good'],
#  ['good', 'and', 'big', 'tawa'],
#  ['this', 'is', 'the', 'best'],
#  ['value', 'for', 'money'],
#  ['good'],
#  ['super'],
#  ['good',
#   'quality',
#   'product',
#   'for',
#   'induction',
#   'it',
#   'will',
#   'not',
#   'work'],
#  ['good'],
#  ['nice'],
#  ['nice', 'tawa'],
#  ['it', 'is', 'nice', 'product', 'go', 'for', 'it'],
#  ['nyc'],
#  ['good', 'product'],
#  ['good', 'but', 'not', 'best'],
#  ['nice', 'one', 'in', 'affordable', 'price', 'go', 'for', 'it'],
#  ['nice', 'tq'],
#  ['super', 'wow', 'good', 'product', 'thanks', 'filpcart'],
#  ['good'],
#  ['nice', 'an', 'good', 'condition', 'recive', 'd'],
#  ['good', 'product'],
#  ['best', 'pan', 'for', 'dosa'],
#  ['good', 'product'],
#  ['super'],
#  ['ok'],
#  ['super', 'dosa'],
#  ['little', 'bit', 'colour', 'off', 'on', 'the', 'tawa'],
#  ['good', 'product', 'i', 'm', 'happy'],
#  ['it', 's', 'really', 'good'],
#  ['good', 'product'],
#  ['very', 'nice', 'product'],
#  ['till', 'now', 'it', 'is', 'working', 'fine', 'satisfied'],
#  ['average', 'product'],
#  ['tawa', 'ok', 'but', 'handle', 'not', 'regid', 'poor', 'handle'],
#  ['good', 'product'],
#  ['excellent',
#   'experience',
#   'i',
#   'really',
#   'liked',
#   'the',
#   'product',
#   'it',
#   'is',
#   'lightweight',
#   'and',
#   'according',
#   'to',
#   'the',
#   'price',
#   'it',
#   'has',
#   'value',
#   'for',
#   'money'],
#  ['i',
#   'am',
#   'satisfied',
#   'with',
#   'the',
#   'product',
#   'it',
#   'is',
#   'non',
#   'sticky',
#   'i',
#   'am',
#   'very',
#   'happy'],
#  ['god'],
#  ['good',
#   'product',
#   'for',
#   'the',
#   'induction',
#   'cooking',
#   'also',
#   'quality',
#   'is',
#   'excellent'],
#  ['good', 'product', 'value', 'of', 'money'],
#  ['good', 'product'],
#  ['super'],
#  ['not', 'good', 'item'],
#  ['nice'],
#  ['ok', 'perfect'],
#  ['it', 's', 'print', 'out'],
#  ['very', 'good'],
#  ['good', 'quality'],
#  ['it',
#   's',
#   'really',
#   'affordable',
#   'and',
#   'cheap',
#   'in',
#   'price',
#   'good',
#   'product',
#   'as',
#   'expected'],
#  ['very', 'nice', 'product'],
#  ['not', 'bad'],
#  ['very', 'nice'],
#  ['good'],
#  ['nice', 'product'],
#  ['nice'],
#  ['good'],
#  ['best'],
#  ['good'],
#  ['nice'],
#  ['thank', 'you', 'flipkart', 'awsome', 'product'],
#  ['good', 'product'],
#  ['perfect', 'product', 'value', 'for', 'money', 'for'],
#  ['superb'],
#  ['very', 'good', 'but', 'cant', 'use', 'for', 'industion', 'stove'],
#  ['something', 'is', 'less'],
#  ['it', 's', 'good'],
#  ['good', 'product'],
#  ['happy', 'ending'],
#  ['good'],
#  ['nice', 'and', 'induction', 'compatible'],
#  ['must', 'buy'],
#  ['very', 'good', 'product', 'liked'],
#  ['ok'],
#  ['bad', 'quality'],
#  ['good', 'product'],
#  ['good', 'built', 'quality'],
#  ['nice'],
#  ['nice'],
#  ['nice'],
#  ['extremely', 'happy'],
#  ['no', 'quality', 'products'],
#  ['superb', 'quality', 'i', 'have', 'satisfied', 'with', 'this', 'product'],
#  ['good'],
#  ['just', 'ok'],
#  ['okay', 'product'],
#  ['very', 'good', 'quality'],
#  ['good', 'pan'],
#  ['its', 'worth', 'for', 'money'],
#  ['good', 'quality', 'in', 'this', 'low', 'price'],
#  ['super', 'product', 'use', 'full'],
#  ['good', 'product'],
#  ['good'],
#  ['good'],
#  ['its', 'good', 'but', 'the', 'size', 'i', 'feel', 'little', 'small'],
#  ['good'],
#  ['good', 'product'],
#  ['good'],
#  ['nice', 'i', 'got', 'the', 'same', 'as', 'pictured'],
#  ['must', 'buy'],
#  ['nice'],
#  ['super', 'product'],
#  ['really', 'nice', 'good', 'product', 'looking', 'great'],
#  ['nice', 'product'],
#  ['nice', 'product', 'worth', 'of', 'money'],
#  ['nice', 'product'],
#  ['nice'],
#  ['top', 'quality', 'product', 'at', 'affordable', 'price'],
#  ['very', 'very', 'nice', 'product'],
#  ['nice', 'product'],
#  ['not', 'bad'],
#  ['good'],
#  ['very', 'very', 'nice'],
#  ['super'],
#  ['so', 'nice'],
#  ['very', 'good'],
#  ['good'],
#  ['it',
#   'would',
#   'be',
#   'star',
#   'if',
#   'handle',
#   'is',
#   'little',
#   'bit',
#   'more',
#   'sturdy',
#   'overall',
#   'good',
#   'experience',
#   'i',
#   'wish',
#   'they',
#   'provide',
#   'a',
#   'spatula',
#   'too'],
#  ['good'],
#  ['this',
#   'sis',
#   'best',
#   'product',
#   'big',
#   'pan',
#   'i',
#   'am',
#   'use',
#   'product',
#   'best',
#   'expression'],
#  ['good', 'dosa', 'tava'],
#  ['this',
#   'is',
#   'an',
#   'excellent',
#   'product',
#   'for',
#   'the',
#   'price',
#   'compact',
#   'practical',
#   'and',
#   'exactly',
#   'what',
#   'was',
#   'required',
#   'to',
#   'fit',
#   'on',
#   'a',
#   'induction',
#   'cookware',
#   'top'],
#  ['this', 'item', 'is', 'good', 'but', 'size', 'is', 'small'],
#  ['good', 'product'],
#  ['good'],
#  ['very', 'good', 'one'],
#  ['ok'],
#  ['nice'],
#  ['excellent'],
#  ['good', 'quality'],
#  ['made', 'in', 'product'],
#  ['good'],
#  ['very', 'good', 'product'],
#  ['it', 's', 'really', 'good'],
#  ['it',
#   's',
#   'very',
#   'very',
#   'nice',
#   'am',
#   'satisfied',
#   'with',
#   'this',
#   'product',
#   'i',
#   'got',
#   'delivery',
#   'on',
#   'time',
#   'thanks',
#   'for',
#   'delivery',
#   'person',
#   'supported',
#   'on',
#   'time',
#   'delivery'],
#  ['worth', 'for', 'it'],
#  ['very', 'amazing'],
#  ['best', 'quality'],
#  ['nyc', 'product', 'in', 'ds', 'price'],
#  ['i',
#   'have',
#   'ordered',
#   'it',
#   'and',
#   'it',
#   'is',
#   'so',
#   'light',
#   'in',
#   'weight',
#   'back',
#   'colour',
#   'is',
#   'not',
#   'permanent',
#   'it',
#   'is',
#   'not',
#   'good',
#   'yes',
#   'but',
#   'okay'],
#  ['very', 'useful', 'product', 'so', 'happy'],
#  ['super', 'product'],
#  ['it', 'is', 'very', 'good'],
#  ['not', 'used', 'yet', 'but', 'looking', 'good'],
#  ['vry', 'vry', 'gud'],
#  ['nice', 'product'],
#  ['good', 'dosa', 'maker'],
#  ['nice', 'product'],
#  ['awesome', 'product'],
#  ['super', 'awesome'],
#  ['iam',
#   'happy',
#   'with',
#   'this',
#   'tawa',
#   'in',
#   'reasonable',
#   'price',
#   'thanku',
#   'flipcart'],
#  ['good', 'one', 'for', 'average', 'cooking', 'purpose'],
#  ['average', 'quality', 'packing', 'no', 'brand', 'name'],
#  ['so', 'good'],
#  ['light', 'weight', 'tawa', 'with', 'aligent', 'design'],
#  ...]

# %%
## Creating Volcabulary List usinhg Word2Vec Model

# %%
pip install gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in c:\users\pc\appdata\roaming\python\python311\site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\pc\appdata\roaming\python\python311\site-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from gensim) (1.12.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from gensim) (7.0.1)
# Requirement already satisfied: wrapt in c:\users\pc\appdata\roaming\python\python311\site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from gensim.models import Word2Vec
from wordcloud import WordCloud
from gensim.models import word2vec
from gensim.models.keyedvectors import KeyedVectors
num_features = 300  #embedding dimension                     
min_word_count = 10                
num_workers = 4       
context = 10                                                                                          
downsampling = 1e-3 

print("Training Word2Vec model ...\n")
w2v = Word2Vec(sentences, workers=num_workers, vector_size=num_features, min_count=min_word_count, window=context, sample=downsampling)
w2v.init_sims(replace=True)
w2v.save("w2v_300features_10minwordcounts_10context") #save trained word2vec model

print("Number of words in the vocabulary list : %d \n" %len(w2v.wv.index_to_key))
print("Show first 10 words in the vocabulary list: \n", w2v.wv.index_to_key[0:10])
# Out:
# Training Word2Vec model ...
#
# Number of words in the vocabulary list : 111
#
# Show first 10 words in the vocabulary list:
#  ['good', 'product', 'nice', 'very', 'it', 'for', 'is', 'quality', 'and', 'super']

# %%
## Averaging Feature Vectors

# %%
def makeFeatureVec(review, model, num_features):
    '''
    Transform a review to a feature vector by averaging feature vectors of words 
    appeared in that review and in the vocabulary list created
    '''
    featureVec = np.zeros((num_features,), dtype="float32")
    nwords = 0.
    index_to_key_set = set(model.wv.index_to_key)  # index_to_key is the vocabulary list of the Word2Vec model
    isZeroVec = True
    for word in review:
        if word in index_to_key_set: 
            nwords += 1
            featureVec = np.add(featureVec, model.wv[word])
            isZeroVec = False
    if not isZeroVec:
        featureVec = np.divide(featureVec, nwords)
    return featureVec

# %%
def getAvgFeatureVecs(reviews, model, num_features):
    '''
    Transform all reviews to feature vectors using makeFeatureVec()
    '''
    counter = 0
    reviewFeatureVecs = np.zeros((len(reviews),num_features),dtype="float32")
    for review in reviews:
        reviewFeatureVecs[counter] = makeFeatureVec(review, model,num_features)
        counter = counter + 1
    return reviewFeatureVecs

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Pc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from gensim.models import Word2Vec
import numpy as np

X_train_cleaned = []
for review in X_train:
    X_train_cleaned.append(cleanText(review, remove_stopwords=True, split_text=True))

trainVector = getAvgFeatureVecs(X_train_cleaned, w2v, num_features)
print("Training set : %d feature vectors with %d dimensions" % trainVector.shape)

# Get feature vectors for validation set
X_test_cleaned = []
for review in X_test:
    X_test_cleaned.append(cleanText(review, remove_stopwords=True, split_text=True))

testVector = getAvgFeatureVecs(X_test_cleaned, w2v, num_features)
print("Validation set : %d feature vectors with %d dimensions" % testVector.shape)
# Out:
# Training set : 2056 feature vectors with 300 dimensions
# Validation set : 229 feature vectors with 300 dimensions

# %%
## Random Forest Classifer

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=1000)
rf.fit(trainVector, y_train)
predictions = rf.predict(testVector)
modelEvaluation(predictions)
# Out:
# Accuracy on validation set: 0.6114
#
# AUC score : 0.5185
#
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.60      0.07      0.12        91
#            1       0.61      0.97      0.75       138
#
#     accuracy                           0.61       229
#    macro avg       0.61      0.52      0.43       229
# weighted avg       0.61      0.61      0.50       229
#
#
# Confusion Matrix :
#  [[  6  85]
#  [  4 134]]

# %%
## LSTM

# %%
pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: keras in c:\users\pc\appdata\roaming\python\python311\site-packages (3.0.5)
# Requirement already satisfied: absl-py in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras) (1.23.5)
# Requirement already satisfied: rich in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras) (0.0.7)
# Requirement already satisfied: h5py in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras) (3.10.0)
# Requirement already satisfied: dm-tree in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras) (0.1.8)
# Requirement already satisfied: ml-dtypes in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras) (0.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\program files\python311\lib\site-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\pc\appdata\roaming\python\python311\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\program files\python311\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\program files\python311\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.0.5)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.23.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: dm-tree in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\pc\appdata\roaming\python\python311\site-packages (from packaging->tensorflow-intel==2.16.1->tensorflow) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\program files\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\program files\python311\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\pc\appdata\roaming\python\python311\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\program files\python311\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\program files\python311\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.0.5)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.23.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: dm-tree in c:\users\pc\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\pc\appdata\roaming\python\python311\site-packages (from packaging->tensorflow-intel==2.16.1->tensorflow) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\program files\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\program files\python311\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
